# %% [markdown]
# # Programación como Herramienta para la Ingeniería 2020-2
# ## Ayudantía 4: Herramientas avanzadas en python
# ### Ayudante: Pablo Seisdedos (pcseisdedos@uc.cl)

# %% [markdown]
# ## Parte 1: NetworkX - Geopandas - osmnx

# %% [markdown]
# Links de interés para graficar:

# %% [markdown]
# - https://osmnx.readthedocs.io/en/stable/osmnx.html#module-osmnx.plot
# - https://pypi.org/project/contextualized/
# - https://geopandas.org/gallery/plotting_with_geoplot.html
# - https://pypi.org/project/mapclassify/

# %%
import osmnx as ox
import fiona
import networkx as nx
import geopandas as gpd
import momepy
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.rcParams['figure.figsize'] = [15, 10]
plt.rcParams.update({'font.size': 16})

# %% [markdown]
# # Obteniendo la información

# %%
ox.config(use_cache=True, log_console=True)
place = 'Valdivia, Chile'
cf = '["highway"~"primary|secondary"]'#'["highway"~"motorway|motorway_link"]'
red_primaria = ox.graph_from_place(place, network_type='drive', custom_filter=cf)

# %%
type(red_primaria)
# Out:
# networkx.classes.multidigraph.MultiDiGraph

# %%
ox.plot_graph(red_primaria, figsize = (10,10), bgcolor = 'w', node_color = 'red', edge_color = 'black', node_alpha = 0)
# Out:
# (<Figure size 720x720 with 1 Axes>, <AxesSubplot:>)

# %%
red_total = ox.graph_from_place(place, network_type='drive')

# %%
ox.plot_graph(red_total, figsize = (10,10), bgcolor = 'w', node_color = 'red', edge_color = 'black', node_alpha = 0)
# Out:
# (<Figure size 720x720 with 1 Axes>, <AxesSubplot:>)

# %%
ox.save_graph_shapefile(red_primaria)
df_arcos_p = gpd.read_file('Data/graph_shapefile/edges.shp')
df_nodos_p = gpd.read_file('Data/graph_shapefile/nodes.shp')
# Out:
# c:\users\yopab\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ox.save_graph_shapefile(red_total)
df_arcos_t = gpd.read_file('Data/graph_shapefile/edges.shp')
df_nodos_t = gpd.read_file('Data/graph_shapefile/nodes.shp')
# Out:
# c:\users\yopab\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Ploteo conjunto

# %%
ax = df_arcos_t.plot(color = "black", figsize = (12,12))
df_arcos_p.plot(ax = ax, color = "red")
# Out:
# c:\users\yopab\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <AxesSubplot:>

# %%
paraderos = ox.geometries.geometries_from_place('Valdivia, Chile', {"highway": "bus_stop"})
# Out:
# c:\users\yopab\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
type(paraderos)
# Out:
# c:\users\yopab\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# geopandas.geodataframe.GeoDataFrame

# %%
paraderos.plot(markersize = 2)
# Out:
# <AxesSubplot:>

# %%
paraderos.crs
# Out:
# c:\users\yopab\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
paraderos
# Out:
#            unique_id       osmid element_type bench   highway  \
# 0    node/1363720932  1363720932         node    no  bus_stop
# 1    node/1368677662  1368677662         node   NaN  bus_stop
# 2    node/1369154318  1369154318         node   NaN  bus_stop
# 3    node/1369154319  1369154319         node   NaN  bus_stop
# 4    node/1369154324  1369154324         node   NaN  bus_stop
# ..               ...         ...          ...   ...       ...
# 375  node/7807735193  7807735193         node   NaN  bus_stop
# 376  node/7866665744  7866665744         node   NaN  bus_stop
# 377  node/7876638402  7876638402         node   NaN  bus_stop
# 378  node/7885927839  7885927839         node   NaN  bus_stop
# 379  node/7902933385  7902933385         node   NaN  bus_stop
#
#                        name         network shelter  \
# 0            20 - 4 - 1 - 3  20 - 4 - 3 - 1     yes
# 1                         2             NaN     NaN
# 2    Campus Miraflores UACH             NaN     NaN
# 3                      1, 3             NaN     NaN
# 4                      1, 3             NaN     NaN
# ..                      ...             ...     ...
# 375                     NaN             NaN     NaN
# 376                     NaN             NaN     NaN
# 377                     NaN             NaN     NaN
# 378                     NaN             NaN     NaN
# 379                Paradero             NaN     NaN
#
#                         geometry  bus  ... operator covered name:es  \
# 0    POINT (-73.23595 -39.81581)  NaN  ...      NaN     NaN     NaN
# 1    POINT (-73.24581 -39.82596)  NaN  ...      NaN     NaN     NaN
# 2    POINT (-73.25137 -39.83275)  NaN  ...      NaN     NaN     NaN
# 3    POINT (-73.24975 -39.82777)  yes  ...      NaN     NaN     NaN
# 4    POINT (-73.25065 -39.82736)  yes  ...      NaN     NaN     NaN
# ..                           ...  ...  ...      ...     ...     ...
# 375  POINT (-73.23038 -39.85406)  yes  ...      NaN     NaN     NaN
# 376  POINT (-73.23131 -39.85106)  yes  ...      NaN     NaN     NaN
# 377  POINT (-73.21526 -39.82466)  yes  ...      NaN     NaN     NaN
# 378  POINT (-73.22931 -39.85215)  yes  ...      NaN     NaN     NaN
# 379  POINT (-73.20592 -39.83459)  NaN  ...      NaN     NaN     NaN
#
#     wheelchair surface source addr:city addr:street  \
# 0          NaN     NaN    NaN       NaN         NaN
# 1          NaN     NaN    NaN       NaN         NaN
# 2          NaN     NaN    NaN       NaN         NaN
# 3          NaN     NaN    NaN       NaN         NaN
# 4          NaN     NaN    NaN       NaN         NaN
# ..         ...     ...    ...       ...         ...
# 375        NaN     NaN    NaN       NaN         NaN
# 376        NaN     NaN    NaN       NaN         NaN
# 377        NaN     NaN    NaN       NaN         NaN
# 378        NaN     NaN    NaN       NaN         NaN
# 379        NaN     NaN    NaN       NaN         NaN
#
#     passenger_information_display   name:en
# 0                             NaN       NaN
# 1                             NaN       NaN
# 2                             NaN       NaN
# 3                             NaN       NaN
# 4                             NaN       NaN
# ..                            ...       ...
# 375                           NaN       NaN
# 376                           NaN       NaN
# 377                           NaN       NaN
# 378                           NaN       NaN
# 379                           NaN  Bus stop
#
# [380 rows x 25 columns]

# %%
x, y = nx.get_node_attributes(red_primaria,"x"), nx.get_node_attributes(red_primaria,"y")
# Out:
# c:\users\yopab\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
nodos = {_id:{"x":x[_id],"y":y[_id]} for _id in x}
# Out:
# c:\users\yopab\appdata\local\programs\python\python38\lib\asyncio\events.py:81: DeprecationWarning: `run_cell_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   self._context.run(self._callback, *self._args)

# %%
nodos
# Out:
# {280622384: {'x': -73.2017049, 'y': -39.8064071},
#  280626286: {'x': -73.4030925, 'y': -39.7192179},
#  280629705: {'x': -73.2012016, 'y': -39.8045696},
#  280632419: {'x': -73.2304098, 'y': -39.8193807},
#  280636659: {'x': -73.2102073, 'y': -39.7883162},
#  280636984: {'x': -73.2000549, 'y': -39.8046392},
#  280638152: {'x': -73.2509568, 'y': -39.7989914},
#  280639045: {'x': -73.250587, 'y': -39.8274997},
#  280639906: {'x': -73.2021824, 'y': -39.8443537},
#  280640696: {'x': -73.1270122, 'y': -39.9272165},
#  309729685: {'x': -73.2321827, 'y': -39.8448759},
#  1183007978: {'x': -73.2323578, 'y': -39.8508667},
#  1183008196: {'x': -73.231955, 'y': -39.8513839},
#  1183008219: {'x': -73.2320792, 'y': -39.851363},
#  1183008280: {'x': -73.2317475, 'y': -39.850689},
#  1183008522: {'x': -73.2319251, 'y': -39.8506588},
#  1183176669: {'x': -73.2573579, 'y': -39.8097433},
#  1183176688: {'x': -73.2575185, 'y': -39.8100366},
#  1183176806: {'x': -73.2577538, 'y': -39.8100041},
#  1183176841: {'x': -73.257596, 'y': -39.809756},
#  1183274158: {'x': -73.2063191, 'y': -39.8409343},
#  1194025070: {'x': -73.2309453, 'y': -39.8175723},
#  1194025109: {'x': -73.2311802, 'y': -39.8199959},
#  1194025112: {'x': -73.2313101, 'y': -39.8202421},
#  1194025150: {'x': -73.2205685, 'y': -39.8309501},
#  1194025169: {'x': -73.2315307, 'y': -39.8179317},
#  1194025180: {'x': -73.2303393, 'y': -39.8194361},
#  1194025201: {'x': -73.2321058, 'y': -39.8184305},
#  1194025227: {'x': -73.2347909, 'y': -39.8168658},
#  1194025242: {'x': -73.2220603, 'y': -39.8277852},
#  1194025359: {'x': -73.231352, 'y': -39.8199559},
#  1194039168: {'x': -73.2207166, 'y': -39.8273703},
#  1194179268: {'x': -73.2071896, 'y': -39.8269508},
#  1268356641: {'x': -73.2283497, 'y': -39.7616745},
#  1268356651: {'x': -73.2411848, 'y': -39.803944},
#  1290396708: {'x': -73.2464203, 'y': -39.8418531},
#  1329488622: {'x': -73.2352014, 'y': -39.827304},
#  1329488623: {'x': -73.235671, 'y': -39.8275606},
#  1329488632: {'x': -73.2355427, 'y': -39.8274687},
#  1358085903: {'x': -73.2108023, 'y': -39.7887667},
#  1358086049: {'x': -73.2111094, 'y': -39.7891545},
#  1358086083: {'x': -73.2103104, 'y': -39.7883675},
#  1369638662: {'x': -73.230633, 'y': -39.8192428},
#  1415770181: {'x': -73.2412584, 'y': -39.8041111},
#  1415770227: {'x': -73.2439003, 'y': -39.8031231},
#  1415786857: {'x': -73.2323698, 'y': -39.8192155},
#  1415786875: {'x': -73.2320482, 'y': -39.8183372},
#  1431225335: {'x': -73.2477724, 'y': -39.8521162},
#  1446338221: {'x': -73.2435268, 'y': -39.8353203},
#  1465753514: {'x': -73.2478768, 'y': -39.8520528},
#  1555291901: {'x': -73.2270854, 'y': -39.823789},
#  1555291929: {'x': -73.235626, 'y': -39.8276009},
#  1555291931: {'x': -73.2495072, 'y': -39.8277766},
#  1555291943: {'x': -73.2408017, 'y': -39.8297859},
#  1574474478: {'x': -73.3442069, 'y': -39.6998274},
#  1574475127: {'x': -73.3967168, 'y': -39.7213542},
#  1696461999: {'x': -73.211283, 'y': -39.7334032},
#  1696462022: {'x': -73.2269477, 'y': -39.76607},
#  1896231007: {'x': -73.230347, 'y': -39.8568475},
#  1896231011: {'x': -73.2304114, 'y': -39.856888},
#  2092560786: {'x': -73.2231564, 'y': -39.8436541},
#  2092560794: {'x': -73.2230907, 'y': -39.8435205},
# -73.2286704 -39.8442103
# -73.2293018 -39.8398617
# -73.2295818 -39.8393841
# -73.2202297 -39.8358123
# -73.2201079 -39.8357497
# -73.2223906 -39.8371484
# -73.2302039 -39.8194404
# -73.2221507 -39.8365908
# -73.2169906 -39.8444169
# -73.2169232 -39.8434043
# -73.230614 -39.8448435
# -73.2312604 -39.8552098
# -73.2321947 -39.8544425
# -73.2297587 -39.8559117
# -73.2278773 -39.8534203
# -73.229138 -39.8548077
# -73.2312924 -39.8535479
# -73.2303829 -39.8540583
# -73.231306 -39.8510555
# -73.215261 -39.8246566
# -73.2293109 -39.8521487
# -73.2059152 -39.8345907

# %%
ox.get_nearest_node(red_primaria, (-39.8259624, -73.2458092))
# Out:
# 1555291931

# %%
df_nodos_p
# Out:
#              y          x       osmid          highway  \
# 0   -39.806407 -73.201705   280622384             None
# 1   -39.719218 -73.403092   280626286             None
# 2   -39.804570 -73.201202   280629705             None
# 3   -39.819381 -73.230410   280632419  traffic_signals
# 4   -39.788316 -73.210207   280636659             None
# ..         ...        ...         ...              ...
# 291 -39.836114 -73.237794  7271137638             None
# 292 -39.840595 -73.257086  7737802325             None
# 293 -39.820430 -73.231210  7935351940             None
# 294 -39.820366 -73.231509  7935351946             None
# 295 -39.845516 -73.248964  8126955956             None
#
#                         geometry
# 0    POINT (-73.20170 -39.80641)
# 1    POINT (-73.40309 -39.71922)
# 2    POINT (-73.20120 -39.80457)
# 3    POINT (-73.23041 -39.81938)
# 4    POINT (-73.21021 -39.78832)
# ..                           ...
# 291  POINT (-73.23779 -39.83611)
# 292  POINT (-73.25709 -39.84059)
# 293  POINT (-73.23121 -39.82043)
# 294  POINT (-73.23151 -39.82037)
# 295  POINT (-73.24896 -39.84552)
#
# [296 rows x 5 columns]

# %%
df_nodos_p["geometry"]
# Out:
# c:\users\yopab\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0      POINT (-73.20170 -39.80641)
# 1      POINT (-73.40309 -39.71922)
# 2      POINT (-73.20120 -39.80457)
# 3      POINT (-73.23041 -39.81938)
# 4      POINT (-73.21021 -39.78832)
#                   ...
# 291    POINT (-73.23779 -39.83611)
# 292    POINT (-73.25709 -39.84059)
# 293    POINT (-73.23121 -39.82043)
# 294    POINT (-73.23151 -39.82037)
# 295    POINT (-73.24896 -39.84552)
# Name: geometry, Length: 296, dtype: geometry

# %%
df_arcos_p.head(5)
# Out:
# c:\users\yopab\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                osmid    ref  \
# 0  [25734753, 488878793, 823495852, 488880592, 48...    204
# 1                                          635412362    204
# 2                                          727874595    204
# 3                                          335610062  T-350
# 4                                          727874595    204
#
#                                                 name    highway  \
# 0  ['Los Girasoles', 'Cruce Ruta 5 (Los Lagos) - ...    primary
# 1                Cruce Ruta 5 (Los Lagos) - Valdivia    primary
# 2                Cruce Ruta 5 (Los Lagos) - Valdivia    primary
# 3  Cruce Calle Los Robles (Valdivia) - Niebla - L...  secondary
# 4                Cruce Ruta 5 (Los Lagos) - Valdivia    primary
#
#               maxspeed  oneway    length lanes        from          to bridge  \
# 0  ['120', '50', '80']       0  2275.476     1   317640424   280622384   None
# 1                   80       1   182.864     2   280622384  5993950064   None
# 2                  120       1   203.294  None  6821011835   280622384   None
# 3                 None       0   607.196  None  1574475127   280626286   None
# 4                  120       1     6.732  None   280629705  6821011835   None
#
#   access junction          u           v  key  \
# 0   None     None  280622384   317640424    0
# 1   None     None  280622384  5993950064    0
# 2   None     None  280622384  6821011835    0
# 3   None     None  280626286  1574475127    0
# 4   None     None  280629705  6821011835    0
#
#                                             geometry
# 0  LINESTRING (-73.20930 -39.82570, -73.20926 -39...
# 1  LINESTRING (-73.20170 -39.80641, -73.20153 -39...
# 2  LINESTRING (-73.20120 -39.80463, -73.20123 -39...
# 3  LINESTRING (-73.39672 -39.72135, -73.39690 -39...
# 4  LINESTRING (-73.20120 -39.80457, -73.20120 -39...

# %%
df_arcos_p.geometry
# Out:
# c:\users\yopab\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0      LINESTRING (-73.20930 -39.82570, -73.20926 -39...
# 1      LINESTRING (-73.20170 -39.80641, -73.20153 -39...
# 2      LINESTRING (-73.20120 -39.80463, -73.20123 -39...
# 3      LINESTRING (-73.39672 -39.72135, -73.39690 -39...
# 4      LINESTRING (-73.20120 -39.80457, -73.20120 -39...
#                              ...
# 461    LINESTRING (-73.20216 -39.79578, -73.20202 -39...
# 462    LINESTRING (-73.20219 -39.79550, -73.20215 -39...
# 463    LINESTRING (-73.20176 -39.79580, -73.20181 -39...
# 464    LINESTRING (-73.23744 -39.83602, -73.23769 -39...
# 465    LINESTRING (-73.23151 -39.82037, -73.23145 -39...
# Name: geometry, Length: 466, dtype: geometry

# %%
paraderos["cercano"] = paraderos.apply(lambda row: ox.get_nearest_node(red_primaria, (row.geometry.y,row.geometry.x)), axis = 1)
# Out:
# c:\users\yopab\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
paraderos
# Out:
#            unique_id       osmid element_type bench   highway  \
# 0    node/1363720932  1363720932         node    no  bus_stop
# 1    node/1368677662  1368677662         node   NaN  bus_stop
# 2    node/1369154318  1369154318         node   NaN  bus_stop
# 3    node/1369154319  1369154319         node   NaN  bus_stop
# 4    node/1369154324  1369154324         node   NaN  bus_stop
# ..               ...         ...          ...   ...       ...
# 375  node/7807735193  7807735193         node   NaN  bus_stop
# 376  node/7866665744  7866665744         node   NaN  bus_stop
# 377  node/7876638402  7876638402         node   NaN  bus_stop
# 378  node/7885927839  7885927839         node   NaN  bus_stop
# 379  node/7902933385  7902933385         node   NaN  bus_stop
#
#                        name         network shelter  \
# 0            20 - 4 - 1 - 3  20 - 4 - 3 - 1     yes
# 1                         2             NaN     NaN
# 2    Campus Miraflores UACH             NaN     NaN
# 3                      1, 3             NaN     NaN
# 4                      1, 3             NaN     NaN
# ..                      ...             ...     ...
# 375                     NaN             NaN     NaN
# 376                     NaN             NaN     NaN
# 377                     NaN             NaN     NaN
# 378                     NaN             NaN     NaN
# 379                Paradero             NaN     NaN
#
#                         geometry  bus  ... covered name:es wheelchair surface  \
# 0    POINT (-73.23595 -39.81581)  NaN  ...     NaN     NaN        NaN     NaN
# 1    POINT (-73.24581 -39.82596)  NaN  ...     NaN     NaN        NaN     NaN
# 2    POINT (-73.25137 -39.83275)  NaN  ...     NaN     NaN        NaN     NaN
# 3    POINT (-73.24975 -39.82777)  yes  ...     NaN     NaN        NaN     NaN
# 4    POINT (-73.25065 -39.82736)  yes  ...     NaN     NaN        NaN     NaN
# ..                           ...  ...  ...     ...     ...        ...     ...
# 375  POINT (-73.23038 -39.85406)  yes  ...     NaN     NaN        NaN     NaN
# 376  POINT (-73.23131 -39.85106)  yes  ...     NaN     NaN        NaN     NaN
# 377  POINT (-73.21526 -39.82466)  yes  ...     NaN     NaN        NaN     NaN
# 378  POINT (-73.22931 -39.85215)  yes  ...     NaN     NaN        NaN     NaN
# 379  POINT (-73.20592 -39.83459)  NaN  ...     NaN     NaN        NaN     NaN
#
#     source addr:city addr:street passenger_information_display   name:en  \
# 0      NaN       NaN         NaN                           NaN       NaN
# 1      NaN       NaN         NaN                           NaN       NaN
# 2      NaN       NaN         NaN                           NaN       NaN
# 3      NaN       NaN         NaN                           NaN       NaN
# 4      NaN       NaN         NaN                           NaN       NaN
# ..     ...       ...         ...                           ...       ...
# 375    NaN       NaN         NaN                           NaN       NaN
# 376    NaN       NaN         NaN                           NaN       NaN
# 377    NaN       NaN         NaN                           NaN       NaN
# 378    NaN       NaN         NaN                           NaN       NaN
# 379    NaN       NaN         NaN                           NaN  Bus stop
#
#         cercano
# 0     447588221
# 1    1555291931
# 2    5035289536
# 3    1555291931
# 4     280639045
# ..          ...
# 375  1896231007
# 376  1183008280
# 377  6283821183
# 378  1183008196
# 379  2618113741
#
# [380 rows x 26 columns]

# %%
nodos[paraderos["cercano"][0]]
# Out:
# c:\users\yopab\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'x': -73.234743, 'y': -39.8168101}

# %%
orig_node = paraderos["cercano"][10]
dest_node = paraderos["cercano"][150]

route1 = nx.shortest_path(red_primaria, orig_node, dest_node, weight = 'length')
fig, ax = ox.plot_graph_route(red_primaria, route1, node_size = 0, figsize=(10,10))

# %%
nx.shortest_path_length(red_primaria, orig_node, dest_node, weight = 'length')
# Out:
# c:\users\yopab\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2778.635

# %%
orig_node = ox.get_nearest_node(red_primaria, (-34.164603, -70.746707))
dest_node = ox.get_nearest_node(red_primaria, (-39.806872, -73.251443))

route2 = nx.shortest_path(red_primaria, orig_node, dest_node, weight = 'length')
fig, ax = ox.plot_graph_route(red_primaria, route2, node_size = 0, figsize=(10,10))

# %%
orig_node = paraderos["cercano"][250]
dest_node = paraderos["cercano"][30]
route3 = nx.shortest_path(red_primaria, orig_node, dest_node, weight = 'length')
routes = [route1, route2, route3]
rc = ['r', 'y', "c"]
fig, ax = ox.plot_graph_routes(red_primaria, routes, route_colors=rc, route_linewidth=6, node_size=0, figsize = (15,15))
# Out:
# c:\users\yopab\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Se demora bastante en ejecutar

# %%
#G = ox.graph.graph_from_address("Santiago, Chile", dist=10000, dist_type='bbox', network_type='all_private', simplify=True)
#ox.plot_graph(G, figsize = (15,15), bgcolor = 'w', node_color = 'red', edge_color = 'black', node_alpha = 0)
# Out:
# c:\users\yopab\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fiona.supported_drivers['KML'] = 'rw'
fiona.supported_drivers['kml'] = 'rw'
#ox.save_graph_shapefile(G)
#df_arcos = gpd.read_file('Data/graph_shapefile/edges.shp')
#df_arcos.to_file("Santiago.kml", driver = "kml")
